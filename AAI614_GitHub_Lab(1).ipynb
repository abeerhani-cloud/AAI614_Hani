# %% [markdown]
# # AAI614 GitHub Lab
#
# [Open in Colab](https://colab.research.google.com/github/abeerhani-cloud/AAI614_Hani/blob/main/AAI614_GitHub_Lab.ipynb)

# %%
print("welcome to github trial file")
# Out:
# welcome to github trial file
