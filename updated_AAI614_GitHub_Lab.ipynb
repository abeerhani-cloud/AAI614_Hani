# %%
# AAI614 GitHub Lab

Open in Colab:
https://colab.research.google.com/github/abeerhani-cloud/AAI614_Hani/blob/main/ah_AAI614_GitHub_Lab.ipynb

# %% [markdown]
# # New Section

# %%
trial file for github access
