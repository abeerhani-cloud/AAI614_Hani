# %%
# AAI614 GitHub Lab

Open in Colab:

https://colab.research.google.com/github/abeerhani/AAI614_Hani/blob/main/AAI614_GitHub_Lab.ipynb

# %%
#trial file for github access
print("hello")
# Out:
# hello
